# %% [markdown]
#  ### Обучение с учителем

# %%
import numpy as np
import pandas as pd

from sklearn.datasets import load_boston
boston = load_boston()
boston
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#         18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#         15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#         13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
# ...

# %%
data = boston.data
target = boston.target
feature_names = boston.feature_names
X = pd.DataFrame(data, columns = feature_names)
y = pd.DataFrame(target, columns = ['price'])
X
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3 , random_state = 42)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
check_test = pd.DataFrame({'y_test': y_test['price'], 
                           'y_pred': y_pred.flatten()}, 
                           columns = ['y_test', 'y_pred'])
check_test
# Out:
#      y_test     y_pred
# 173    23.6  28.648960
# 274    32.4  36.495014
# 491    13.6  15.411193
# 72     22.8  25.403213
# 452    16.1  18.855280
# ..      ...        ...
# 441    17.1  17.403672
# 23     14.5  13.385941
# 225    50.0  39.983425
# 433    14.3  16.682863
# 447    12.6  18.285618
#
# [152 rows x 2 columns]

# %%
from sklearn.metrics import r2_score

r2_score(y_test, y_pred)
# Out:
# 0.7112260057484973

# %%
# Хотел сравнить результаты с Excel. В файл схранил датафрейм с data и price. С помощью Анализа данных в  Excel рассчитал r2
writer = pd.ExcelWriter('example.xlsx', engine='xlsxwriter')
X.to_excel(writer, 'Sheet1')
Y.to_excel(writer, 'Sheet2')
writer.save()

# %%
excel_data = pd.read_excel('example.xlsx', sheet_name = 'Sheet3')
excel_data

# В Excel получается r2 = 0,74
# Out:
#                 ВЫВОД ИТОГОВ    Unnamed: 1          Unnamed: 2    Unnamed: 3  \
# 0                        NaN           NaN                 NaN           NaN
# 1   Регрессионная статистика           NaN                 NaN           NaN
# 2            Множественный R      0.860606                 NaN           NaN
# 3                  R-квадрат      0.740643                 NaN           NaN
# 4    Нормированный R-квадрат       0.73379                 NaN           NaN
# 5         Стандартная ошибка        4.7453                 NaN           NaN
# 6                 Наблюдения           506                 NaN           NaN
# 7                        NaN           NaN                 NaN           NaN
# 8       Дисперсионный анализ           NaN                 NaN           NaN
# 9                        NaN            df                  SS            MS
# 10                 Регрессия            13             31637.5       2433.65
# ...
